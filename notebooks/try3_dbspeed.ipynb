# %%
import sqlite3
import time

conn = sqlite3.connect("db/pred_data.db")
cur = conn.cursor()

start = time.time()
cur.execute("""
SELECT * FROM Attention
WHERE timestamp BETWEEN '2025-07-21 00:00:00' AND '2025-08-21 23:59:59';
""")
rows = cur.fetchall()
end = time.time()

print(f"Rows fetched: {len(rows)}")
print(f"Query time: {end - start:.3f} seconds")
# Out:
# Rows fetched: 6058
# Query time: 0.117 seconds

# %%
import sqlite3
import time

conn = sqlite3.connect("db/pred_data2.db")
cur = conn.cursor()

start = time.time()
cur.execute("""
SELECT * FROM Attention
WHERE timestamp BETWEEN '2025-07-21 00:00:00' AND '2025-08-21 23:59:59';
""")
rows = cur.fetchall()
end = time.time()

print(f"Rows fetched: {len(rows)}")
print(f"Query time: {end - start:.3f} seconds")
# Out:
# Rows fetched: 6058
# Query time: 0.032 seconds

# %%
import sqlite3
import os

folder = "db"  # change this

for filename in os.listdir(folder):
    if filename.endswith(".db"):
        db_path = os.path.join(folder, filename)
        print(f"Processing {db_path}...")
        conn = sqlite3.connect(db_path)
        cur = conn.cursor()

        # List all tables
        cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = [t[0] for t in cur.fetchall()]

        for table in tables:
            # Check if table has a timestamp column
            cur.execute(f"PRAGMA table_info({table});")
            columns = [c[1] for c in cur.fetchall()]
            if "timestamp" in columns:
                try:
                    cur.execute(f"CREATE INDEX IF NOT EXISTS idx_{table}_timestamp ON {table}(timestamp);")
                    print(f"  Index created on {table}.timestamp")
                except sqlite3.OperationalError as e:
                    print(f"  Failed on {table}: {e}")
        conn.commit()
        conn.close()
# Out:
# Processing /home/arkiven4/Documents/Project/Vale/tinymonitor-web/db/threshold_data.db...
#   Index created on Attention.timestamp
#   Index created on DTAAD.timestamp
#   Index created on MAD_GAN.timestamp
#   Index created on TranAD.timestamp
#   Index created on DAGMM.timestamp
#   Index created on USAD.timestamp
#   Index created on OmniAnomaly.timestamp
# Processing /home/arkiven4/Documents/Project/Vale/tinymonitor-web/db/pred_data.db...
#   Index created on Attention.timestamp
#   Index created on DTAAD.timestamp
#   Index created on MAD_GAN.timestamp
#   Index created on TranAD.timestamp
#   Index created on DAGMM.timestamp
#   Index created on USAD.timestamp
#   Index created on OmniAnomaly.timestamp
# Processing /home/arkiven4/Documents/Project/Vale/tinymonitor-web/db/pred_data2.db...
#   Index created on Attention.timestamp
#   Index created on DTAAD.timestamp
#   Index created on MAD_GAN.timestamp
#   Index created on TranAD.timestamp
#   Index created on DAGMM.timestamp
# ...
